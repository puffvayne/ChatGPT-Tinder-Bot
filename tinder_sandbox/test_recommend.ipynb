# %%
import sys
import pathlib
CURR_DIR = pathlib.Path().resolve()
PROJECT_DIR = CURR_DIR.parent
sys.path.append(str(PROJECT_DIR))
print(f"[INFO] - append directory to path: {PROJECT_DIR}")
# Out:
# [INFO] - append directory to path: D:\Dev\Code\ChatGPT-Tinder-Bot

# %%
from src.tinder import TinderAPI, TINDER_URL
from src.utils import to_json, read_json
import json
import requests
from pprint import pp

# %%
token = ''

# %%
tinder_api = TinderAPI(token)

# %%
recs = tinder_api.get_recommendations()

# %%
meta_v1 = tinder_api.meta_v1()

# %%
meta_v1
# Out:
# {'status': 200,
#  'account': {},
#  'client_resources': {'rate_card': {'carousel': [{'slug': 'unlimited_likes'},
#     {'slug': 'boost'},
#     {'slug': 'who_sees_you'},
#     {'slug': 'passport'},
#     {'slug': 'your_profile'},
#     {'slug': 'super_like'},
#     {'slug': 'undo'},
#     {'slug': 'no_ads'}]},
#   'plus_screen': ['unlimited_swipes',
#    'boost',
#    'who_you_see',
#    'who_sees_you',
#    'passport',
#    'your_profile',
#    'super_like',
#    'undo',
#    'hide_ads'],
#   'platinum_paywall_carousel': ['swipe_note',
#    'priority_likes',
#    'priority_messages',
#    'likes_you',
#    'remaining_features',
#    'gold',
#    'plus']},
#  'notifications': [],
#  'rating': {'likes_remaining': 100,
#   'super_likes': {'remaining': 0,
#    'alc_remaining': 0,
#    'new_alc_remaining': 0,
#    'allotment': 1,
#    'superlike_refresh_amount': 5,
#    'superlike_refresh_interval': 1,
#    'superlike_refresh_interval_unit': 'd',
#    'resets_at': None}},
# ...

# %%
to_json(meta_v1, 'meta_v1.json')

# %%
# for rec_p in recs:
#     pp(rec_p.info())
#     print()

# %%
# recs_v1 = tinder_api.get_recommendations_v1()
# to_json(recs_v1, 'recs_v1.json')

# %%
# profile = tinder_api.profile()

# %%
# profile.max_distance

# %%
# tinder_api.like('5d1069911df6e117006f865f')
